# %%
import json, os, random, re, unicodedata, urllib, urllib2, sys

# %%
# TODO: Getting the refresh_token should happen online with an OAuth dialog, and the refresh token
# and client secret should be stored here instead of the username and password.
# Or we should have a onetime username/password dialog in Python, and store same.

# ~/.config/esdr/auth.json should look like:
# {
#    "grant_type" : "password",
#    "client_id" : <client id>,
#    "client_secret" : <client secret>,
#    "username" : <email address>,
#    "password" : <actual password>
# }

class Esdr:
    def __init__(self, auth_file, prefix='https://esdr.cmucreatelab.org'):
        self.prefix = prefix
        self.auth_file = auth_file
        self.tokens = None

    @staticmethod
    def create_client(client_name):
        client_secret = '%032x' % random.randrange(16**32)

        data = {'displayName' : client_name,
                'clientName' :  re.sub('\W+', '_', client_name),
                'clientSecret' : client_secret}

        request = urllib2.Request('http://esdr.cmucreatelab.org/api/v1/clients', 
                                  data=json.dumps(data), 
                                  headers={'Content-Type': 'application/json'})

        print urllib2.urlopen(request).read()

        # Write this to esdr-auth.json
        return {
            'grant_type': 'password',
            'client_id': data['clientName'],
            'client_secret': client_secret,
            'username': 'EDIT ME',
            'password': 'EDIT ME'
        }
    
    @staticmethod
    # Replace sequences of non-word characters with '_'
    def make_identifier(name):
         name = ''.join(c for c in unicodedata.normalize('NFD', unicode(name))
                      if unicodedata.category(c) != 'Mn')
         return re.sub(r'\W+', '_', name).strip('_')

    def api(self, http_type, path, json_data=None, oauth=True):
        headers = {}
        data = None
        if json_data:
            if http_type == 'POST' or http_type == 'PUT':
                headers['Content-Type'] = 'application/json'
                data = json.dumps(json_data)
            elif http_type == 'GET':
                # Yuck:  work-around urllib.urlencode not coping with unicode
                json_data_utf8 = {k:v.encode('utf8') for k,v in json_data.iteritems()}
                path += '?' + urllib.urlencode(json_data_utf8)
        if oauth:
            headers['Authorization'] = 'Bearer %s' % self.get_access_token()
        url = self.prefix + path
        request = urllib2.Request(url, data=data, headers=headers)
        if http_type == 'PUT':
            request.get_method = lambda: 'PUT'
        try:
            return json.loads(urllib2.urlopen(request).read())
        except Exception, e:
            raise Exception, 'While trying to %s %s (data=%s, headers=%s), %s' % (http_type, url, data, headers, e), sys.exc_info()[2]

    def get_access_token(self):
        if not self.tokens:
            self.get_tokens()
        return self.tokens['access_token']
    
    def get_tokens(self):
        try:
            auth = json.load(open(self.auth_file))
        except Exception, e:
            raise Exception, 'While trying to read authorization file %s, %s' % (self.auth_file, e), sys.exc_info()[2]
        self.tokens = self.api('POST',
                               '/oauth/token',
                               json.load(open(self.auth_file)),
                               oauth=False)

    def query(self, path, args):
        response = self.api('GET', path, args)
        return response['data']['rows']
    
    def query_first(self, path, args):
        rows = self.query(path, args)
        if len(rows) == 0:
            return None
        else:
            return rows[0];

    def get_product_by_name(self, name):
        return self.query_first('/api/v1/products', {'where':'name=%s' % name})

    def get_product_by_id(self, id):
        return self.query_first('/api/v1/products', {'where':'id=%d' % id})
            
#    def get_device_by_name(self, product, device_name):
#        if device_name in self.device_map:
#            return {'name': device_name, 'id': self.device_map[device_name]}
#        else:
#            return None
    
    def get_or_create_device(self, product, serial_number, name=None):
        device = self.get_device_by_serial_number(product, serial_number)
        if not device:
            self.create_device(product, serial_number, name=name)
            device = self.get_device_by_serial_number(product, serial_number)
        return device
    
    def get_device_by_serial_number(self, product, name):
        response = self.api('GET', '/api/v1/devices', {'whereAnd': 'productId=%d,serialNumber=%s' % (product['id'], serial_number)})
        if response['data']['totalCount'] == 0:
            return None
        elif response['data']['totalCount'] == 1:
            return response['data']['rows'][0]
        else:
            raise Exception('get_device_by_serial_number: found more than one device?')
        
    def create_device(self, product, serial_number, name=None):
        if name == None:
            name = serial_number
        device = self.api('POST',
                          '/api/v1/products/%d/devices' % product['id'], 
                          {
                              'name':name,
                              'serialNumber':serial_number
                          })['data']
        return device
    
    def get_or_create_feed(self, device):
        feed = self.get_feed(device)
        if not feed:
            self.create_feed(device)
            feed = self.get_feed(device)
        return feed
    
    def get_feed(self, device):
        return self.query_first('/api/v1/feeds', {'where':'deviceId=%d' % device['id']})
    
    # TODO(rsargent): add more args here, go back and set lat, lon
    def create_feed(self, device):
        product = self.get_product_by_id(device['productId'])
        response = self.api('POST',
                 '/api/v1/devices/%d/feeds' % device['id'],
                 {
                    'name': '%s %s' % (device['name'], product['name']),
                    'exposure':'outdoor',
                    'isPublic':1,
                    'isMobile':0
                 })
        return response
    
    def upload(self, feed, data):
        return self.api('PUT', '/api/v1/feeds/%s' % feed['id'], data)
    
    def get_tile_prefix(self, feed, channel_name):
        return self.prefix + '/api/v1/feeds/%d/channels/%s/tiles' % (feed['id'], channel_name)
    
    def create_product(self, name, pretty_name, vendor, description, default_channel_specs={}):
        return self.api('POST', '/api/v1/products', {
            'name': name,
            'prettyName': pretty_name,
            'vendor': vendor,
            'description': description,
            'defaultChannelSpecs': default_channel_specs
        })
            
#Create product:
#esdr.api('POST', '/api/v1/products', {
#   "name" : "ACHD",
#   "prettyName" : "ACHD",
#   "vendor" : "ACHD",
#   "description" : "A sensor operated by the Allegheny County Health Department (ACHD)",
#   "defaultChannelSpecs" : {}
#})

# %%
#esdr = Esdr()
#product = esdr.get_product_by_name('TestProduct')
#device = esdr.get_or_create_device(product, 'TestDevice')
#feed = esdr.get_or_create_feed(device)
#data = {'channel_names': ['a', 'b', 'c'],
#        'data': [[1417524480, 1, 1, 1],
#                 [1417524481, 2, 3, 4],
#                 [1417524482, 3, 5, 7]]}
#
#esdr.upload(feed, data)

# %%
# Esdr.create_client('timemachine1 airnow uploader')
# Out:
# {"code":201,"status":"success","data":{"displayName":"timemachine1 airnow uploader","clientName":"timemachine1_airnow_uploader"}}

# %%
# !git diff
# Out:
# diff --git a/esdr-library.ipynb b/esdr-library.ipynb
# index 52a0e78..7559361 100644
# --- a/esdr-library.ipynb
# +++ b/esdr-library.ipynb
# @@ -1,7 +1,7 @@
#  {
#   "metadata": {
#    "name": "",
# -  "signature": "sha256:7150e0f1ef4963726b2de9db40db3c2030cdb32f06563008b0474c0b915767fa"
# +  "signature": "sha256:b667458dce30851a77e2f473b9f0c009e035ce4dc3db320fedbeeab4c438d034"
#   },
#   "nbformat": 3,
#   "nbformat_minor": 0,
# @@ -12,12 +12,12 @@
#       "cell_type": "code",
#       "collapsed": false,
#       "input": [
# -      "import json, os, random, re, urllib, urllib2, sys"
# +      "import json, os, random, re, unicodedata, urllib, urllib2, sys"
#       ],
#       "language": "python",
#       "metadata": {},
#       "outputs": [],
# -     "prompt_number": 2
# +     "prompt_number": 15
#      },
#      {
#       "cell_type": "code",
# @@ -64,7 +64,14 @@
#        "            'username': 'EDIT ME',\n",
#        "            'password': 'EDIT ME'\n",
#        "        }\n",
# -      "        \n",
# +      "    \n",
# +      "    @staticmethod\n",
# +      "    # Replace sequences of non-word characters with '_'\n",
# +      "    def make_identifier(name):\n",
# +      "         name = ''.join(c for c in unicodedata.normalize('NFD', unicode(name))\n",
# +      "                      if unicodedata.category(c) != 'Mn')\n",
# +      "         return re.sub(r'\\W+', '_', name).strip('_')\n",
# +      "\n",
#        "    def api(self, http_type, path, json_data=None, oauth=True):\n",
#        "        headers = {}\n",
#        "        data = None\n",
# @@ -125,33 +132,31 @@
#        "#        else:\n",
#        "#            return None\n",
#        "    \n",
# -      "    def get_or_create_device(self, product, name, serial_number=None):\n",
# -      "        device = self.get_device_by_name(product, name)\n",
# +      "    def get_or_create_device(self, product, serial_number, name=None):\n",
# +      "        device = self.get_device_by_serial_number(product, serial_number)\n",
#        "        if not device:\n",
# -      "            self.create_device(product, name, serial_number)\n",
# -      "            device = self.get_device_by_name(product, name)\n",
# +      "            self.create_device(product, serial_number, name=name)\n",
# +      "            device = self.get_device_by_serial_number(product, serial_number)\n",
#        "        return device\n",
#        "    \n",
# -      "    def get_device_by_name(self, product, name):\n",
# -      "        response = self.api('GET', '/api/v1/devices', {'whereAnd': 'productId=%d,name=%s' % (product['id'], name)})\n",
# +      "    def get_device_by_serial_number(self, product, name):\n",
# +      "        response = self.api('GET', '/api/v1/devices', {'whereAnd': 'productId=%d,serialNumber=%s' % (product['id'], serial_number)})\n",
#        "        if response['data']['totalCount'] == 0:\n",
#        "            return None\n",
#        "        elif response['data']['totalCount'] == 1:\n",
#        "            return response['data']['rows'][0]\n",
#        "        else:\n",
# -      "            raise Exception('get_device_by_name: found more than one device?')\n",
# +      "            raise Exception('get_device_by_serial_number: found more than one device?')\n",
#        "        \n",
# -      "    def create_device(self, product, name, serial_number=None):\n",
# -      "        if serial_number == None:\n",
# -      "            serial_number = re.sub(r'\\s+', '_', name)\n",
# +      "    def create_device(self, product, serial_number, name=None):\n",
# +      "        if name == None:\n",
# +      "            name = serial_number\n",
#        "        device = self.api('POST',\n",
#        "                          '/api/v1/products/%d/devices' % product['id'], \n",
#        "                          {\n",
#        "                              'name':name,\n",
#        "                              'serialNumber':serial_number\n",
#        "                          })['data']\n",
# -      "        print device\n",
# -      "        print \"'%s':%s\" % (name, device['id'])\n",
#        "        return device\n",
#        "    \n",
#        "    def get_or_create_feed(self, device):\n",
# @@ -204,7 +209,7 @@
#       "language": "python",
#       "metadata": {},
#       "outputs": [],
# -     "prompt_number": 1
# +     "prompt_number": 25
#      },
#      {
#       "cell_type": "code",
